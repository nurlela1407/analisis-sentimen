# %%
# import library
import numpy as np 
import pandas as pd
import nltk
import string
import re
import os

import matplotlib.pyplot as plt
# %matplotlib inline

import keras
import keras.utils
from sklearn import preprocessing
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D, Flatten

from functools import partial
from keras import metrics

# %%
MAX_SEQUENCES_LENGTH = 50 # Maximum kata pada kalimat
MAX_NB_WORDS = 6000 # Vocabulary size
EMBEDDING_DIM = 50 # Dimensions of Glove word vector kadang bisa juga 100

# %%
# open dataset,save on dataframe
df = pd.read_csv("dataset/dataset_manual.csv",encoding="ISO-8859-1")

# membuka data slang (data yang akan dibenarkan)
with open('slang.txt') as file:
    slang_map = dict(map(str.strip, line.partition('\t')[::2])
    for line in file if line.strip())
    
df.head()
# Out:
#        created_at  screen_name  \
# 0  5/1/2021 16:48    theoholan
# 1   5/2/2021 1:38   knb_rmdhna
# 2   5/2/2021 5:51        _afaz
# 3   5/2/2021 7:19  PolitikBRIN
# 4  5/3/2021 14:12    KoloElang
#
#                                                 text  Label
# 0                      itu mah konflik rebutan tanah      0
# 1   Karena ga ada urgensinya. Ga ada ancaman inva...      0
# 2   ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...      0
# 3   Analisis yang dirumuskan dari Klaster Politik...      0
# 4   Bisa tidak? Palestina taat secara kaffah dala...      0

# %%
# drop column created_at and screen_name
df = df.drop(['created_at', 'screen_name'], axis=1)

# %%
df.head()
# Out:
#                                                 text  Label
# 0                      itu mah konflik rebutan tanah      0
# 1   Karena ga ada urgensinya. Ga ada ancaman inva...      0
# 2   ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...      0
# 3   Analisis yang dirumuskan dari Klaster Politik...      0
# 4   Bisa tidak? Palestina taat secara kaffah dala...      0

# %%
#remove user
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
    return input_txt   
df['remove_user'] = np.vectorize(remove_pattern)(df['text'], "@[\w]*")

# %%
df
# Out:
#                                                    text  Label  \
# 0                         itu mah konflik rebutan tanah      0
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...      0
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...      0
# 3      Analisis yang dirumuskan dari Klaster Politik...      0
# 4      Bisa tidak? Palestina taat secara kaffah dala...      0
# ...                                                 ...    ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...      1
# 1643   @JatIkhwan Saya kok ngelihatnya gencatan senj...      1
# 1644   Mungkin mereka bergembira mau merayakan Genca...      2
# 1645   Agak lucu aja sih liat orang pada jadi die ha...      0
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...      2
#
#                                             remove_user  \
# 0                         itu mah konflik rebutan tanah
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...
# 3      Analisis yang dirumuskan dari Klaster Politik...
# 4      Bisa tidak? Palestina taat secara kaffah dala...
# ...                                                 ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...
# 1643    Saya kok ngelihatnya gencatan senjata ini se...
# 1644   Mungkin mereka bergembira mau merayakan Genca...
# 1645   Agak lucu aja sih liat orang pada jadi die ha...
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...
#
#                                             remove_http  \
# 0                         itu mah konflik rebutan tanah
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...
# 3      Analisis yang dirumuskan dari Klaster Politik...
# 4      Bisa tidak? Palestina taat secara kaffah dala...
# ...                                                 ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...
# 1643    Saya kok ngelihatnya gencatan senjata ini se...
# 1644   Mungkin mereka bergembira mau merayakan Genca...
# 1645   Agak lucu aja sih liat orang pada jadi die ha...
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...
#
#                                             tweet_clean  \
# 0                          [mah, konflik, rebut, tanah]
# 1     [ga, urgensi, ga, ancam, invasi, militer, nega...
# 2     [valid, , , , , , , , , kemarin, smpat, nonton...
# 3     [analisis, rumus, klaster, politik, negeri, is...
# 4     [palestina, taat, kaffah, islam, ganti, demokr...
# ...                                                 ...
# 1642  [satu, hati, satu, tekadsatulan, langkah, buru...
# 1643  [ngelihatnya, gencat, senjata, sengaja, ngulur...
# 1644  [gembira, raya, gencat, senjata, israel, hamas...
# 1645  [lucu, aja, sih, liat, orang, die, hard, fans,...
# 1646  [zionis, dah, langgar, gencat, senjata, ni, fu...
#
#                                                   Tweet
# 0                               mah konflik rebut tanah
# 1     ga urgensi ga ancam invasi militer negara kawa...
# 2     valid kemarin smpat nonton salah wawancara man...
# 3     analisis rumus klaster politik negeri isu inte...
# 4     palestina taat kaffah islam ganti demokrasi si...
# ...                                                 ...
# 1642  satu hati satu tekadsatulan langkah buruh indo...
# 1643  ngelihatnya gencat senjata sengaja ngulur krn ...
# 1644  gembira raya gencat senjata israel hamas tari ...
# 1645  lucu aja sih liat orang die hard fans konflik ...
# 1646        zionis dah langgar gencat senjata ni fuck u
#
# [1580 rows x 6 columns]

# %%
#import stopword
from nltk.corpus import stopwords 
#stopwords_indonesia = stopwords.words('indonesian')
# Create Stopword
with open("stopword.txt", "r") as f:
    stopwords_indonesia = f.readline().split()
    
 
#import sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

#tokenize
from nltk.tokenize import TweetTokenizer

# mengganti kata2 slang menjadi lebih baku
slang_words = sorted(slang_map, key=len, reverse=True) # longest first for regex
regex = re.compile(r"\b({})\b".format("|".join(map(re.escape, slang_words))))
replaceSlang = partial(regex.sub, lambda m: slang_map[m.group(1)])
 
# Happy Emoticons
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])
 
# Sad Emoticons
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

additional_char = set([
    'nTTTTT', 'T\n', '&amp',
    'n1','n2','n3','n4','n5', 'n6', 'n7', 'n8', 'n9',
    'x8', 'x80', 'x81', 'x82', 'x83', 'x84', 'x85', 'x86', 'x87', 'x88', 'x89', 'x8a', 'x8b', 'x8c', 'x8d', 'x8e', 'x8f',
    'x9', 'x90', 'x91', 'x92', 'x93', 'x94', 'x95', 'x96', 'x97', 'x98', 'x99', 'x9c', 'x9d', 'x9e', 'x9f',
    'xa', 'xa0', 'xa1', 'xa2', 'xa3', 'xa4', 'xa5', 'xa6', 'xa7', 'xa8', 'xa9', 'xaa', 'xac', 'xad', 'xae',
    'xb', 'xb0', 'xb1', 'xb2', 'xb3', 'xb4', 'xb5', 'xb6', 'xb7', 'xb8', 'xb9', 'xba', 'xab', 'xbb', 'xbc', 'xbd',
    'xc', 'xc1', 'xc2', 'xe2', 'xef', 'xf', 'xf0' 
    ])
 
# all emoticons (happy + sad)
emoticons = emoticons_happy.union(emoticons_sad)
 
def clean_tweets(tweet):
    
    #Convert to lower case
    tweet  = tweet.lower()
    
    #Convert www.* or https?://* to ''
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','',tweet)
    
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    
    #Remove additional white spaces
    tweet = re.sub('[\s]+', ' ', tweet)
    
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1',tweet)
    
    # remove old style retweet text "RT" dan karakter yang tidak dibutuhkan
    tweet = re.sub(r"b'rt", '', tweet)
    tweet = re.sub(r"b'", '', tweet)
    tweet = re.sub(r'b"', '', tweet)
    
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
 
    tweets_clean = []    
    for word in tweet_tokens:
        if (word not in stopwords_indonesia and # remove stopwords
              word not in emoticons and # remove emoticons
                    word not in additional_char and #remove add_char
                        word not in string.punctuation): # remove punctuation
            #tweets_clean.append(word)
            stem_word = stemmer.stem(word) # stemming word
            tweets_clean.append(stem_word)
 
    return tweets_clean

# %%
df['tweet_clean'] = df['remove_user'].apply(lambda x: clean_tweets(x))

# %%
df
# Out:
#                                                    text  Label  \
# 0                         itu mah konflik rebutan tanah      0
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...      0
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...      0
# 3      Analisis yang dirumuskan dari Klaster Politik...      0
# 4      Bisa tidak? Palestina taat secara kaffah dala...      0
# ...                                                 ...    ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...      1
# 1643   @JatIkhwan Saya kok ngelihatnya gencatan senj...      1
# 1644   Mungkin mereka bergembira mau merayakan Genca...      2
# 1645   Agak lucu aja sih liat orang pada jadi die ha...      0
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...      2
#
#                                             remove_user  \
# 0                         itu mah konflik rebutan tanah
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...
# 3      Analisis yang dirumuskan dari Klaster Politik...
# 4      Bisa tidak? Palestina taat secara kaffah dala...
# ...                                                 ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...
# 1643    Saya kok ngelihatnya gencatan senjata ini se...
# 1644   Mungkin mereka bergembira mau merayakan Genca...
# 1645   Agak lucu aja sih liat orang pada jadi die ha...
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...
#
#                                             remove_http  \
# 0                         itu mah konflik rebutan tanah
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...
# 3      Analisis yang dirumuskan dari Klaster Politik...
# 4      Bisa tidak? Palestina taat secara kaffah dala...
# ...                                                 ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...
# 1643    Saya kok ngelihatnya gencatan senjata ini se...
# 1644   Mungkin mereka bergembira mau merayakan Genca...
# 1645   Agak lucu aja sih liat orang pada jadi die ha...
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...
#
#                                             tweet_clean  \
# 0                     [itu, mah, konflik, rebut, tanah]
# 1     [karena, ga, urgensi, ga, ancam, invasi, milit...
# 2     [ini, valid, , , , , , , , , kemarin, saya, sm...
# 3     [analisis, yang, rumus, dari, klaster, politik...
# 4     [bisa, tidak, palestina, taat, cara, kaffah, d...
# ...                                                 ...
# 1642  [satu, hati, satu, tekad, satulan, langkah, sa...
# 1643  [saya, kok, ngelihatnya, gencat, senjata, ini,...
# 1644  [mungkin, mereka, gembira, mau, raya, gencat, ...
# 1645  [agak, lucu, aja, sih, liat, orang, pada, jadi...
# 1646  [zionis, dah, langgar, gencat, senjata, ni, fu...
#
#                                                   Tweet
# 0                               mah konflik rebut tanah
# 1     ga urgensi ga ancam invasi militer negara kawa...
# 2     valid kemarin smpat nonton salah wawancara man...
# 3     analisis rumus klaster politik negeri isu inte...
# 4     palestina taat kaffah islam ganti demokrasi si...
# ...                                                 ...
# 1642  satu hati satu tekadsatulan langkah buruh indo...
# 1643  ngelihatnya gencat senjata sengaja ngulur krn ...
# 1644  gembira raya gencat senjata israel hamas tari ...
# 1645  lucu aja sih liat orang die hard fans konflik ...
# 1646        zionis dah langgar gencat senjata ni fuck u
#
# [1580 rows x 6 columns]

# %%
df.drop(df.columns[[2,3,4]], axis = 1, inplace = True)

# %%
# delete missing value 
nan_value = float('NaN')
df.replace('', nan_value, inplace=True)
df.dropna(subset=['text'], inplace=True)

# %%
df
# Out:
#                                                    text  Label  \
# 0                         itu mah konflik rebutan tanah      0
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...      0
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...      0
# 3      Analisis yang dirumuskan dari Klaster Politik...      0
# 4      Bisa tidak? Palestina taat secara kaffah dala...      0
# ...                                                 ...    ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...      1
# 1643   @JatIkhwan Saya kok ngelihatnya gencatan senj...      1
# 1644   Mungkin mereka bergembira mau merayakan Genca...      2
# 1645   Agak lucu aja sih liat orang pada jadi die ha...      0
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...      2
#
#                                             remove_user  \
# 0                         itu mah konflik rebutan tanah
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...
# 3      Analisis yang dirumuskan dari Klaster Politik...
# 4      Bisa tidak? Palestina taat secara kaffah dala...
# ...                                                 ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...
# 1643    Saya kok ngelihatnya gencatan senjata ini se...
# 1644   Mungkin mereka bergembira mau merayakan Genca...
# 1645   Agak lucu aja sih liat orang pada jadi die ha...
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...
#
#                                             remove_http  \
# 0                         itu mah konflik rebutan tanah
# 1      Karena ga ada urgensinya. Ga ada ancaman inva...
# 2      ini valid Ã°ÂÂÂ¯ kemarin saya smpat nonton ...
# 3      Analisis yang dirumuskan dari Klaster Politik...
# 4      Bisa tidak? Palestina taat secara kaffah dala...
# ...                                                 ...
# 1642   Satukan hati, satukan tekad,satulan langkah, ...
# 1643    Saya kok ngelihatnya gencatan senjata ini se...
# 1644   Mungkin mereka bergembira mau merayakan Genca...
# 1645   Agak lucu aja sih liat orang pada jadi die ha...
# 1646   Zionis dah langgar gencatan senjata ni. Fuck ...
#
#                                             tweet_clean  \
# 0                     [itu, mah, konflik, rebut, tanah]
# 1     [karena, ga, urgensi, ga, ancam, invasi, milit...
# 2     [ini, valid, , , , , , , , , kemarin, saya, sm...
# 3     [analisis, yang, rumus, dari, klaster, politik...
# 4     [bisa, tidak, palestina, taat, cara, kaffah, d...
# ...                                                 ...
# 1642  [satu, hati, satu, tekad, satulan, langkah, sa...
# 1643  [saya, kok, ngelihatnya, gencat, senjata, ini,...
# 1644  [mungkin, mereka, gembira, mau, raya, gencat, ...
# 1645  [agak, lucu, aja, sih, liat, orang, pada, jadi...
# 1646  [zionis, dah, langgar, gencat, senjata, ni, fu...
#
#                                                   Tweet
# 0                               mah konflik rebut tanah
# 1     ga urgensi ga ancam invasi militer negara kawa...
# 2     valid kemarin smpat nonton salah wawancara man...
# 3     analisis rumus klaster politik negeri isu inte...
# 4     palestina taat kaffah islam ganti demokrasi si...
# ...                                                 ...
# 1642  satu hati satu tekadsatulan langkah buruh indo...
# 1643  ngelihatnya gencat senjata sengaja ngulur krn ...
# 1644  gembira raya gencat senjata israel hamas tari ...
# 1645  lucu aja sih liat orang die hard fans konflik ...
# 1646        zionis dah langgar gencat senjata ni fuck u
#
# [1580 rows x 6 columns]

# %%
# menghitung Label sentimen (menampilkan tabel pembagian label sentimen)
labels = df.Label
labels_count = labels.value_counts()
labels_count.plot(kind="bar", x='Label', y='Jumlah', color='red')
print(labels.value_counts())
# Out:
# 0    673
# 2    534
# 1    373
# Name: Label, dtype: int64

# %%
# convert to CSV
df.to_csv('stopword&stemming.csv', encoding='utf-8', index=False)

# %%
# Prepare to X as Feature
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.text)
sequences = tokenizer.texts_to_sequences(df.text)
# Banyak kata yang telah di tokenizer
word_index = tokenizer.word_index

# %%
print('Found %d unique words.' % len(word_index))
# Out:
# Found 6802 unique words.

# %%
X = pad_sequences(sequences, maxlen=MAX_SEQUENCES_LENGTH, padding='post')

# %%
# Prepare to y as label
y = df["Label"]
y = to_categorical(y)

# %%
classes = ['0', '1', '2']

# %%
# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=20, stratify=y)

# %%
# open Glove
print('Indexing word vectors.')

embeddings_index = {}
f = open(os.path.join('dataset/glove/vectors.txt'), encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Indexing word vectors.
# Found 331286 word vectors.

# %%
# Use GloVe as Word Embedding
hits = 0
misses = 0
index = []
num_words = min(MAX_NB_WORDS, len(word_index))
embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1
        index.append(word)

# %%
test = embeddings_index.get("netizen")
test
# Out:
# array([-4.327230e-01, -3.119420e-01,  1.094491e+00, -2.145950e-01,
#         7.534390e-01,  1.659070e+00,  4.936180e-01,  1.409000e-03,
#         4.884600e-01,  2.542550e-01, -4.979390e-01,  5.617340e-01,
#         7.850000e-04,  4.132720e-01, -1.368150e-01, -9.046870e-01,
#         1.362670e-01,  4.538210e-01, -5.378070e-01, -3.954030e-01,
#         4.325460e-01,  1.985550e-01,  9.402100e-01,  7.971500e-01,
#        -3.500120e-01, -1.429267e+00, -2.684250e-01,  1.794200e-02,
#        -5.229970e-01, -3.316800e-02, -6.168300e-02, -3.128350e-01,
#         6.554350e-01,  6.181870e-01, -6.873700e-01, -4.817520e-01,
#        -3.157320e-01,  5.082510e-01, -7.406850e-01,  3.074100e-01,
#        -1.201028e+00, -1.213599e+00,  1.140920e-01,  3.905700e-02,
#         6.468660e-01, -1.947500e-02, -4.191220e-01, -5.519950e-01,
#         6.553630e-01,  4.248600e-01], dtype=float32)

# %%
# Embedding layer with glove
embedding_layer = Embedding(len(word_index) + 1, EMBEDDING_DIM, input_length=MAX_SEQUENCES_LENGTH,weights=[embedding_matrix],trainable=True)

# %%
# Create Model CNN
# model 2
def create_model():
    model = Sequential()
    model.add(embedding_layer)
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
#     model.add(GlobalMaxPooling1D())
    model.add(Dropout(0.3))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', padding='same'))
    model.add(Dropout(0.3))
    model.add(GlobalMaxPooling1D())
#     model.add(Flatten())
    model.add(Dense(32,activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    return model

# %%
# Train Model
cnn_model = create_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            340150
#
#  conv1d (Conv1D)             (None, 50, 128)           19328
#
#  dropout (Dropout)           (None, 50, 128)           0
#
#  max_pooling1d (MaxPooling1D  (None, 25, 128)          0
#  )
#
#  dropout_1 (Dropout)         (None, 25, 128)           0
#
#  conv1d_1 (Conv1D)           (None, 25, 64)            24640
#
#  dropout_2 (Dropout)         (None, 25, 64)            0
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 386,297
# Trainable params: 386,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
cnn_history = cnn_model.fit(X_train, y_train, epochs=40, validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 45/45 [==============================] - 5s 40ms/step - loss: 1.1941 - accuracy: 0.3650 - val_loss: 1.0775 - val_accuracy: 0.4494
# Epoch 2/40
# 45/45 [==============================] - 1s 27ms/step - loss: 1.0729 - accuracy: 0.4233 - val_loss: 1.0638 - val_accuracy: 0.4304
# Epoch 3/40
# 45/45 [==============================] - 1s 25ms/step - loss: 1.0630 - accuracy: 0.4311 - val_loss: 1.0627 - val_accuracy: 0.4367
# Epoch 4/40
# 45/45 [==============================] - 1s 26ms/step - loss: 1.0580 - accuracy: 0.4536 - val_loss: 1.0484 - val_accuracy: 0.5000
# Epoch 5/40
# 45/45 [==============================] - 1s 25ms/step - loss: 1.0623 - accuracy: 0.4381 - val_loss: 1.0303 - val_accuracy: 0.4873
# Epoch 6/40
# 45/45 [==============================] - 1s 33ms/step - loss: 1.0380 - accuracy: 0.4775 - val_loss: 1.0258 - val_accuracy: 0.4557
# Epoch 7/40
# 45/45 [==============================] - 1s 25ms/step - loss: 1.0192 - accuracy: 0.4873 - val_loss: 1.0161 - val_accuracy: 0.5127
# Epoch 8/40
# 45/45 [==============================] - 1s 25ms/step - loss: 1.0030 - accuracy: 0.4944 - val_loss: 0.9969 - val_accuracy: 0.5000
# Epoch 9/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.9905 - accuracy: 0.4909 - val_loss: 1.0064 - val_accuracy: 0.4810
# Epoch 10/40
# 45/45 [==============================] - 1s 25ms/step - loss: 0.9422 - accuracy: 0.5141 - val_loss: 0.9729 - val_accuracy: 0.5316
# Epoch 11/40
# 45/45 [==============================] - 1s 30ms/step - loss: 0.9538 - accuracy: 0.5148 - val_loss: 0.9841 - val_accuracy: 0.5759
# Epoch 12/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.9102 - accuracy: 0.5598 - val_loss: 0.9618 - val_accuracy: 0.5823
# Epoch 13/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.8695 - accuracy: 0.5999 - val_loss: 0.9264 - val_accuracy: 0.6076
# Epoch 14/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.8429 - accuracy: 0.6188 - val_loss: 0.8983 - val_accuracy: 0.6329
# Epoch 15/40
# 45/45 [==============================] - 1s 30ms/step - loss: 0.7584 - accuracy: 0.6646 - val_loss: 0.8700 - val_accuracy: 0.6646
# Epoch 16/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.7205 - accuracy: 0.6779 - val_loss: 0.8480 - val_accuracy: 0.6456
# Epoch 17/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.6671 - accuracy: 0.7166 - val_loss: 0.8654 - val_accuracy: 0.6392
# Epoch 18/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.6043 - accuracy: 0.7511 - val_loss: 0.8501 - val_accuracy: 0.6392
# Epoch 19/40
# 45/45 [==============================] - 1s 25ms/step - loss: 0.5582 - accuracy: 0.7623 - val_loss: 0.8351 - val_accuracy: 0.6519
# Epoch 20/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.4783 - accuracy: 0.8073 - val_loss: 0.8610 - val_accuracy: 0.6076
# Epoch 21/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.4398 - accuracy: 0.8361 - val_loss: 0.8576 - val_accuracy: 0.6392
# Epoch 22/40
# 45/45 [==============================] - 1s 25ms/step - loss: 0.3895 - accuracy: 0.8523 - val_loss: 0.9259 - val_accuracy: 0.6456
# Epoch 23/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.3168 - accuracy: 0.8805 - val_loss: 0.9432 - val_accuracy: 0.6329
# Epoch 24/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.2802 - accuracy: 0.8966 - val_loss: 0.9679 - val_accuracy: 0.6329
# Epoch 25/40
# 45/45 [==============================] - 1s 25ms/step - loss: 0.2514 - accuracy: 0.9037 - val_loss: 1.0133 - val_accuracy: 0.6519
# Epoch 26/40
# 45/45 [==============================] - 1s 26ms/step - loss: 0.2289 - accuracy: 0.9156 - val_loss: 1.0844 - val_accuracy: 0.6329
# Epoch 27/40
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1974 - accuracy: 0.9226 - val_loss: 1.0689 - val_accuracy: 0.6392
# Epoch 28/40
# 45/45 [==============================] - 1s 27ms/step - loss: 0.1764 - accuracy: 0.9416 - val_loss: 1.1561 - val_accuracy: 0.6266
# Epoch 29/40
# 45/45 [==============================] - 2s 41ms/step - loss: 0.1496 - accuracy: 0.9501 - val_loss: 1.3375 - val_accuracy: 0.6076
# Epoch 30/40
# 45/45 [==============================] - 2s 37ms/step - loss: 0.1430 - accuracy: 0.9529 - val_loss: 1.2869 - val_accuracy: 0.6392
# Epoch 31/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.1371 - accuracy: 0.9522 - val_loss: 1.3556 - val_accuracy: 0.5949
# Epoch 32/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.1271 - accuracy: 0.9606 - val_loss: 1.3129 - val_accuracy: 0.6139
# Epoch 33/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0941 - accuracy: 0.9655 - val_loss: 1.4140 - val_accuracy: 0.6013
# Epoch 34/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.1015 - accuracy: 0.9662 - val_loss: 1.4711 - val_accuracy: 0.6076
# Epoch 35/40
# 45/45 [==============================] - 1s 27ms/step - loss: 0.0818 - accuracy: 0.9747 - val_loss: 1.4561 - val_accuracy: 0.5886
# Epoch 36/40
# 45/45 [==============================] - 1s 28ms/step - loss: 0.0732 - accuracy: 0.9761 - val_loss: 1.5657 - val_accuracy: 0.6139
# Epoch 37/40
# 45/45 [==============================] - 1s 27ms/step - loss: 0.0790 - accuracy: 0.9726 - val_loss: 1.5857 - val_accuracy: 0.6013
# Epoch 38/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0822 - accuracy: 0.9677 - val_loss: 1.6356 - val_accuracy: 0.6076
# Epoch 39/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0885 - accuracy: 0.9719 - val_loss: 1.5748 - val_accuracy: 0.5759
# Epoch 40/40
# 45/45 [==============================] - 1s 29ms/step - loss: 0.0498 - accuracy: 0.9831 - val_loss: 1.6371 - val_accuracy: 0.5949

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
ypred = cnn_model.predict(X_test)
cnn_accuracy = accuracy_score(y_test.argmax(axis=-1),ypred.argmax(axis=-1))
print("CNN Accuracy:",cnn_accuracy)
cnn_cn = confusion_matrix(y_test.argmax(axis=-1),ypred.argmax(axis=-1))
plt.subplots(figsize=(20,16))
sns.heatmap(cnn_cn,annot=True,fmt="1d",cmap="Blues",cbar=True,xticklabels=classes,yticklabels=classes)
plt.xlabel("Predicted",fontsize=15)
plt.ylabel("Actual",fontsize=15)
# plt.savefig('model60_e40.png')
plt.show()
# Out:
# CNN Accuracy: 0.5949367088607594

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test.argmax(axis=-1), ypred.argmax(axis=-1),target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.55      0.57        67
#            1       0.49      0.54      0.51        37
#            2       0.69      0.69      0.69        54
#
#     accuracy                           0.59       158
#    macro avg       0.59      0.59      0.59       158
# weighted avg       0.60      0.59      0.60       158

# %%
fig3, axe1 = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
axe1[0].plot(cnn_history.history["accuracy"],label="accuracy")
axe1[0].plot(cnn_history.history["val_accuracy"],label="accuracy")
axe1[0].legend(['train', 'val'], loc='upper left')
axe1[1].plot(cnn_history.history["loss"],label="loss")
axe1[1].plot(cnn_history.history["val_loss"],label="loss")
axe1[1].legend(['train', 'val'], loc='upper left')
axe1[0].title.set_text("CNN Accuracy")
axe1[1].title.set_text("CNN Loss")
axe1[0].set_xlabel("Epoch")
axe1[1].set_xlabel("Epoch")
axe1[0].set_ylabel("Rate")
plt.show()
